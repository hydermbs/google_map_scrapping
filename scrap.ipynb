# %%
#import essential libraries

import ssl
context = ssl._create_unverified_context()
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as ureq
import logging
import pandas as pd

# %%
#Provided the base Url
map_url = "https://www.google.com/maps/search/Pizza+in+London"
map_url
# Out:
# 'https://www.google.com/maps/search/Pizza+in+London'

# %%
url_client = requests.get(map_url)
rest_card = url_client.text
#Parse and Clean HTML
rest_html = bs(rest_card,'html.parser')
rest_html
# Out:
# <!DOCTYPE html>
# ...

# %%
restaurants = rest_html.findAll("div",{"class":"Nv2PK THOPZb CpccDe"})

restaurants
# Out:
# []

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_maps",
  "q": "pizza",
  "ll": "@51.5030319,-0.3008878,11.31z",
  "type": "search",
  "api_key": "secret_api_key"
}

search = GoogleSearch(params)
results = search.get_dict()
local_results = results["local_results"]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 from serpapi import GoogleSearch
#       3 params = {
#       4   "engine": "google_maps",
#       5   "q": "pizza",
#    (...)
#       8   "api_key": "secret_api_key"
#       9 }
#      11 search = GoogleSearch(params)
#
# ImportError: cannot import name 'GoogleSearch' from 'serpapi' (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/serpapi/__init__.py)
